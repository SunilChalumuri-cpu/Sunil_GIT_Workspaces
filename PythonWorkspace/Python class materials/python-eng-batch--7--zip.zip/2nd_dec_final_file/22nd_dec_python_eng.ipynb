# %%
with open("test.txt" , 'w') as f :
    f.write("this is my python eng batch")

# %%
with open("test.txt" , 'w') as f :
    f.write("my name is sudhanshu")

# %%
with open("test.txt" , 'a') as f :
    f.write("my name is sudhanshu")

# %%
with open('test1.txt' ,'r') as f :
    f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 with open('test1.txt' ,'r') as f :
#       2     f.read()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test1.txt'

# %%
with open('test.txt' ,'r') as f :
    print(f.read())
# Out:
# my name is sudhanshumy
#  name is sudhanshumy name
#  is sudhanshumy name is sudhan
#  shumy name is sudhanshumy name i
#  s sudhanshumy name is sudhanshumy
#   name is sudhanshumy name is sudhanshu

# %%
def read_file(filename) :
    with open(filename,'r') as f :
            return f.read()

# %%
read_file('test.txt')
# Out:
# 'my name is sudhanshumy\n name is sudhanshumy name \n is sudhanshumy name is sudhan\n shumy name is sudhanshumy name i\n s sudhanshumy name is sudhanshumy\n  name is sudhanshumy name is sudhanshu'

# %%
type(read_file('test.txt'))
# Out:
# str

# %%
with open("test.txt" , 'w') as f :
    f.write("this is my python eng batch\n i am the mentor of this batch\n ,  i am discusssion pyton file operation\n in this batch")

# %%
with open("test.txt" , 'r') as f :
    print(f.read(10))
# Out:
# this is my

# %%
with open("test.txt" , 'r') as f :
    print(f.readline())
# Out:
# this is my python eng batch

# %%
with open("test.txt" , 'r') as f :
    print(f.readline(2))
# Out:
# th

# %%
with open("test.txt" , 'r') as f :
    print(f.readlines())
# Out:
# ['this is my python eng batch\n', ' i am the mentor of this batch\n', ' ,  i am discusssion pyton file operation\n', ' in this batch']

# %%
with open("test.txt" , 'r') as f :
    print(f.tell())
# Out:
# 0

# %%
with open("test.txt" , 'r') as f :
    f.seek(5)
    print(f.read())
# Out:
# is my python eng batch
#  i am the mentor of this batch
#  ,  i am discusssion pyton file operation
#  in this batch

# %%
import zipfile

with zipfile.ZipFile('2nd_dec_final_file.zip' , 'w') as f :
    f.write('22nd_dec_python_eng.ipynb')
